# %% [markdown]
# # Kano PHC Accessibility — Results Review
# This notebook loads the published summary tables and displays the principal indicators.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
master = pd.read_csv(ROOT / 'data/processed/tables/kano_phc_master_project_results.csv')
master

# %%
scenario = pd.read_csv(ROOT / 'data/processed/tables/kano_phc_expansion_scenario_comparison.csv')
scenario
